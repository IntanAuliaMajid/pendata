# %% [markdown]
# # Fuzzy C-Means

# %% [markdown]
# ## Konsep dasar
#
# Fuzzy C-Means adalah cara untuk mengelompokkan data ke dalam beberapa grup (cluster), tapi setiap data bisa masuk ke lebih dari satu grup. Artinya, satu data bisa masuk ke lebih dari satu cluster, dengan nilai keanggotaan antara 0 dan 1, dan jumlah total keanggotaan untuk satu data adalah 1.

# %% [markdown]
# ### Langkah Algoritma
# Menghitung cluster (C)
# tentukan nilai (M) secara umum 2
# matriks keanggotaan (U)

# %% [markdown]
# tampilkan 2 itereasi

# %%
import pandas as pd
import numpy as np

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Baca file Excel dan pastikan data dalam format numerik NumPy array
df = pd.read_excel("fuzzy c-means.xlsx")
data = df[['X1', 'X2']].to_numpy(dtype=float)

# %%
# STEP 2: Parameter FCM
c = 2       # jumlah cluster
m = 2.0     # fuzzy exponent
n_data = data.shape[0]

# STEP 3: Inisialisasi derajat keanggotaan awal U0 secara acak
U = np.random.dirichlet(np.ones(c), size=n_data).T

print("=== Derajat Keanggotaan Awal (U0) ===")
for j in range(n_data):
    degrees = [round(U[i, j], 4) for i in range(c)]
    print(f"Data ke-{j+1}: {degrees}")

# Fungsi update pusat cluster
def update_centers(U, data, m):
    um = U ** m
    return (um @ data) / np.sum(um, axis=1)[:, None]

# Fungsi update derajat keanggotaan
def update_membership(data, centers, m):
    c = centers.shape[0]
    n = data.shape[0]
    new_U = np.zeros((c, n))
    for j in range(n):
        for i in range(c):
            dist_ij = np.linalg.norm(data[j] - centers[i])
            if dist_ij == 0:
                new_U[:, j] = 0
                new_U[i, j] = 1
                break
            else:
                sum_term = 0
                for k in range(c):
                    dist_kj = np.linalg.norm(data[j] - centers[k])
                    sum_term += (dist_ij / dist_kj) ** (2 / (m - 1))
                new_U[i, j] = 1 / sum_term
    return new_U

# Fungsi objektif FCM
def compute_objective_function(U, centers, data, m):
    total = 0
    for i in range(c):
        for j in range(n_data):
            dist_sq = np.linalg.norm(data[j] - centers[i]) ** 2
            total += (U[i][j] ** m) * dist_sq
    return total

# === ITERASI 1 ===
print("\n=== Iterasi 1 ===")

# Langkah 1: Hitung pusat cluster dari U0
centers = update_centers(U, data, m)
print("\nPusat Cluster (Centroids) Iterasi 1:")
for i, center in enumerate(centers):
    print(f"Cluster {i+1}: {center}")

# Langkah 2: Hitung derajat keanggotaan baru U1
U = update_membership(data, centers, m)
print("\nDerajat Keanggotaan Baru (U1):")
for j in range(n_data):
    degrees = [round(U[i, j], 4) for i in range(c)]
    print(f"Data ke-{j+1}: {degrees}")

# Langkah 3: Hitung fungsi objektif
J = compute_objective_function(U, centers, data, m)
print(f"\nFungsi Objektif Iterasi 1 (J1): {J:.4f}")
# Out:
# === Derajat Keanggotaan Awal (U0) ===
# Data ke-1: [np.float64(0.5629), np.float64(0.4371)]
# Data ke-2: [np.float64(0.1127), np.float64(0.8873)]
# Data ke-3: [np.float64(0.7876), np.float64(0.2124)]
# Data ke-4: [np.float64(0.4513), np.float64(0.5487)]
# Data ke-5: [np.float64(0.8175), np.float64(0.1825)]
#
# === Iterasi 1 ===
#
# Pusat Cluster (Centroids) Iterasi 1:
# Cluster 1: [4.44795514 5.44795514]
# Cluster 2: [2.90217486 3.90217486]
#
# Derajat Keanggotaan Baru (U1):
# Data ke-1: [np.float64(0.2333), np.float64(0.7667)]
# Data ke-2: [np.float64(0.1196), np.float64(0.8804)]
# Data ke-3: [np.float64(0.0045), np.float64(0.9955)]
# Data ke-4: [np.float64(0.7994), np.float64(0.2006)]
# Data ke-5: [np.float64(0.7205), np.float64(0.2795)]
#
# Fungsi Objektif Iterasi 1 (J1): 20.2369

# %%
# === ITERASI 2 ===
print("\n=== Iterasi 2 ===")

# Langkah 1: Hitung pusat cluster dari U1
centers = update_centers(U, data, m)
print("\nPusat Cluster (Centroids) Iterasi 2:")
for i, center in enumerate(centers):
    print(f"Cluster {i+1}: {center}")

# Langkah 2: Hitung derajat keanggotaan baru U2
U = update_membership(data, centers, m)
print("\nDerajat Keanggotaan Baru (U2):")
for j in range(n_data):
    degrees = [round(U[i, j], 4) for i in range(c)]
    print(f"Data ke-{j+1}: {degrees}")

# Langkah 3: Hitung fungsi objektif
J = compute_objective_function(U, centers, data, m)
print(f"\nFungsi Objektif Iterasi 2 (J2): {J:.4f}")
# Out:
# === Iterasi 2 ===
#
# Pusat Cluster (Centroids) Iterasi 2:
# Cluster 1: [6.15460239 7.15460239]
# Cluster 2: [2.38617286 3.38617286]
#
# Derajat Keanggotaan Baru (U2):
# Data ke-1: [np.float64(0.0674), np.float64(0.9326)]
# Data ke-2: [np.float64(0.0086), np.float64(0.9914)]
# Data ke-3: [np.float64(0.0365), np.float64(0.9635)]
# Data ke-4: [np.float64(0.9982), np.float64(0.0018)]
# Data ke-5: [np.float64(0.9675), np.float64(0.0325)]
#
# Fungsi Objektif Iterasi 2 (J2): 6.0362

# %%
# STEP 2: Parameter FCM
c = 3       # jumlah cluster
m = 2.0     # fuzzy exponent
n_data = data.shape[0]

# STEP 3: Inisialisasi derajat keanggotaan awal U0 secara acak
U = np.random.dirichlet(np.ones(c), size=n_data).T

# Fungsi update pusat cluster
def update_centers(U, data, m):
    um = U ** m
    return (um @ data) / np.sum(um, axis=1)[:, None]

# Fungsi update derajat keanggotaan
def update_membership(data, centers, m):
    c = centers.shape[0]
    n = data.shape[0]
    new_U = np.zeros((c, n))
    for j in range(n):
        for i in range(c):
            dist_ij = np.linalg.norm(data[j] - centers[i])
            if dist_ij == 0:
                new_U[:, j] = 0
                new_U[i, j] = 1
                break
            else:
                sum_term = 0
                for k in range(c):
                    dist_kj = np.linalg.norm(data[j] - centers[k])
                    sum_term += (dist_ij / dist_kj) ** (2 / (m - 1))
                new_U[i, j] = 1 / sum_term
    return new_U

# Fungsi objektif FCM
def compute_objective_function(U, centers, data, m):
    total = 0
    for i in range(c):
        for j in range(n_data):
            dist_sq = np.linalg.norm(data[j] - centers[i]) ** 2
            total += (U[i][j] ** m) * dist_sq
    return total

# Parameter konvergensi
epsilon = 1e-5 # Error toleransi untuk konvergensi (0.00001)
max_iter = 100

print("=== Derajat Keanggotaan Awal (U0) ===")
for j in range(n_data):
    degrees = [round(U[i, j], 4) for i in range(c)]
    print(f"Data ke-{j+1}: {degrees}")

J_prev = 0
for iteration in range(1, max_iter + 1):
    print(f"\n=== Iterasi {iteration} ===")

    # Langkah 1: Hitung pusat cluster
    centers = update_centers(U, data, m)
    print("\nPusat Cluster (Centroids):")
    for i, center in enumerate(centers):
        print(f"Cluster {i+1}: {center}")

    # Langkah 2: Hitung derajat keanggotaan baru
    U = update_membership(data, centers, m)
    print("\nDerajat Keanggotaan Baru:")
    for j in range(n_data):
        degrees = [round(U[i, j], 4) for i in range(c)]
        print(f"Data ke-{j+1}: {degrees}")

    # Langkah 3: Hitung fungsi objektif
    J = compute_objective_function(U, centers, data, m)
    print(f"\nFungsi Objektif Iterasi {iteration} (J{iteration}): {J:.6f}")

    # Cek konvergensi
    if iteration > 1 and abs(J - J_prev) < epsilon:
        print("\nKonvergen! Iterasi dihentikan.")
        break

    J_prev = J

if iteration == max_iter:
    print("\nMaksimum iterasi tercapai tanpa konvergensi.")
# Out:
# === Derajat Keanggotaan Awal (U0) ===
# Data ke-1: [np.float64(0.3445), np.float64(0.1149), np.float64(0.5406)]
# Data ke-2: [np.float64(0.1785), np.float64(0.7878), np.float64(0.0337)]
# Data ke-3: [np.float64(0.2489), np.float64(0.2927), np.float64(0.4584)]
# Data ke-4: [np.float64(0.0803), np.float64(0.2134), np.float64(0.7062)]
# Data ke-5: [np.float64(0.5599), np.float64(0.3693), np.float64(0.0707)]
#
# === Iterasi 1 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [4.88608719 5.88608719]
# Cluster 2: [3.03909809 4.03909809]
# Cluster 3: [3.9239719 4.9239719]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.1563), np.float64(0.5676), np.float64(0.2761)]
# Data ke-2: [np.float64(0.0912), np.float64(0.7036), np.float64(0.2052)]
# Data ke-3: [np.float64(0.0004), np.float64(0.9978), np.float64(0.0018)]
# Data ke-4: [np.float64(0.6996), np.float64(0.099), np.float64(0.2014)]
# Data ke-5: [np.float64(0.5691), np.float64(0.1621), np.float64(0.2688)]
#
# Fungsi Objektif Iterasi 1 (J1): 13.065288
#
# === Iterasi 2 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.19915056 7.19915056]
# Cluster 2: [2.45646175 3.45646175]
# Cluster 3: [3.93505055 4.93505055]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0592), np.float64(0.7549), np.float64(0.1859)]
# Data ke-2: [np.float64(0.0111), np.float64(0.9368), np.float64(0.0521)]
# Data ke-3: [np.float64(0.0211), np.float64(0.7317), np.float64(0.2472)]
# Data ke-4: [np.float64(0.9877), np.float64(0.0031), np.float64(0.0092)]
# Data ke-5: [np.float64(0.9096), np.float64(0.0283), np.float64(0.0621)]
#
# Fungsi Objektif Iterasi 2 (J2): 5.270452
#
# === Iterasi 3 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.44717092 7.44717092]
# Cluster 2: [1.98462877 2.98462877]
# Cluster 3: [2.45137471 3.45137471]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0219), np.float64(0.6698), np.float64(0.3083)]
# Data ke-2: [np.float64(0.0), np.float64(0.9988), np.float64(0.0012)]
# Data ke-3: [np.float64(0.0192), np.float64(0.2216), np.float64(0.7591)]
# Data ke-4: [np.float64(0.9725), np.float64(0.0121), np.float64(0.0154)]
# Data ke-5: [np.float64(0.9738), np.float64(0.0118), np.float64(0.0144)]
#
# Fungsi Objektif Iterasi 3 (J3): 2.740393
#
# === Iterasi 4 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.49858808 7.49858808]
# Cluster 2: [1.73372908 2.73372908]
# Cluster 3: [2.71934995 3.71934995]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0148), np.float64(0.8334), np.float64(0.1518)]
# Data ke-2: [np.float64(0.0031), np.float64(0.8768), np.float64(0.1201)]
# Data ke-3: [np.float64(0.0061), np.float64(0.0465), np.float64(0.9474)]
# Data ke-4: [np.float64(0.9645), np.float64(0.0132), np.float64(0.0223)]
# Data ke-5: [np.float64(0.9777), np.float64(0.0089), np.float64(0.0134)]
#
# Fungsi Objektif Iterasi 4 (J4): 2.142071
#
# === Iterasi 5 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50604817 7.50604817]
# Cluster 2: [1.52836638 2.52836638]
# Cluster 3: [2.93769818 3.93769818]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0085), np.float64(0.9229), np.float64(0.0686)]
# Data ke-2: [np.float64(0.0087), np.float64(0.7912), np.float64(0.2002)]
# Data ke-3: [np.float64(0.0003), np.float64(0.0018), np.float64(0.9979)]
# Data ke-4: [np.float64(0.9614), np.float64(0.0123), np.float64(0.0263)]
# Data ke-5: [np.float64(0.9776), np.float64(0.008), np.float64(0.0145)]
#
# Fungsi Objektif Iterasi 5 (J5): 1.844461
#
# === Iterasi 6 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50793512 7.50793512]
# Cluster 2: [1.42432738 2.42432738]
# Cluster 3: [2.95528003 3.95528003]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0056), np.float64(0.9496), np.float64(0.0447)]
# Data ke-2: [np.float64(0.0118), np.float64(0.7249), np.float64(0.2633)]
# Data ke-3: [np.float64(0.0002), np.float64(0.0008), np.float64(0.999)]
# Data ke-4: [np.float64(0.9614), np.float64(0.0118), np.float64(0.0268)]
# Data ke-5: [np.float64(0.9779), np.float64(0.0076), np.float64(0.0145)]
#
# Fungsi Objektif Iterasi 6 (J6): 1.796080
#
# === Iterasi 7 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50808646 7.50808646]
# Cluster 2: [1.36886325 2.36886325]
# Cluster 3: [2.93429924 3.93429924]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0043), np.float64(0.9608), np.float64(0.0349)]
# Data ke-2: [np.float64(0.0133), np.float64(0.6775), np.float64(0.3092)]
# Data ke-3: [np.float64(0.0004), np.float64(0.0016), np.float64(0.998)]
# Data ke-4: [np.float64(0.962), np.float64(0.0116), np.float64(0.0264)]
# Data ke-5: [np.float64(0.9782), np.float64(0.0075), np.float64(0.0143)]
#
# Fungsi Objektif Iterasi 7 (J7): 1.779929
#
# === Iterasi 8 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50788128 7.50788128]
# Cluster 2: [1.33283006 2.33283006]
# Cluster 3: [2.91303719 3.91303719]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0035), np.float64(0.9672), np.float64(0.0293)]
# Data ke-2: [np.float64(0.0141), np.float64(0.6427), np.float64(0.3432)]
# Data ke-3: [np.float64(0.0006), np.float64(0.0027), np.float64(0.9967)]
# Data ke-4: [np.float64(0.9625), np.float64(0.0114), np.float64(0.0261)]
# Data ke-5: [np.float64(0.9784), np.float64(0.0074), np.float64(0.0142)]
#
# Fungsi Objektif Iterasi 8 (J8): 1.772024
#
# === Iterasi 9 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50767379 7.50767379]
# Cluster 2: [1.30702264 2.30702264]
# Cluster 3: [2.89518255 3.89518255]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.003), np.float64(0.9715), np.float64(0.0255)]
# Data ke-2: [np.float64(0.0146), np.float64(0.6162), np.float64(0.3693)]
# Data ke-3: [np.float64(0.0009), np.float64(0.0038), np.float64(0.9953)]
# Data ke-4: [np.float64(0.963), np.float64(0.0113), np.float64(0.0257)]
# Data ke-5: [np.float64(0.9786), np.float64(0.0073), np.float64(0.0141)]
#
# Fungsi Objektif Iterasi 9 (J9): 1.767607
#
# === Iterasi 10 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50750891 7.50750891]
# Cluster 2: [1.28758705 2.28758705]
# Cluster 3: [2.88048714 3.88048714]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0027), np.float64(0.9745), np.float64(0.0228)]
# Data ke-2: [np.float64(0.0149), np.float64(0.5954), np.float64(0.3898)]
# Data ke-3: [np.float64(0.0012), np.float64(0.0048), np.float64(0.994)]
# Data ke-4: [np.float64(0.9633), np.float64(0.0112), np.float64(0.0255)]
# Data ke-5: [np.float64(0.9787), np.float64(0.0073), np.float64(0.014)]
#
# Fungsi Objektif Iterasi 10 (J10): 1.764953
#
# === Iterasi 11 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50738098 7.50738098]
# Cluster 2: [1.27249752 2.27249752]
# Cluster 3: [2.8683799 3.8683799]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0024), np.float64(0.9768), np.float64(0.0208)]
# Data ke-2: [np.float64(0.0151), np.float64(0.5787), np.float64(0.4062)]
# Data ke-3: [np.float64(0.0014), np.float64(0.0058), np.float64(0.9928)]
# Data ke-4: [np.float64(0.9636), np.float64(0.0111), np.float64(0.0253)]
# Data ke-5: [np.float64(0.9788), np.float64(0.0072), np.float64(0.0139)]
#
# Fungsi Objektif Iterasi 11 (J11): 1.763281
#
# === Iterasi 12 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50728077 7.50728077]
# Cluster 2: [1.26054453 2.26054453]
# Cluster 3: [2.85836659 3.85836659]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0022), np.float64(0.9786), np.float64(0.0192)]
# Data ke-2: [np.float64(0.0152), np.float64(0.5653), np.float64(0.4195)]
# Data ke-3: [np.float64(0.0016), np.float64(0.0066), np.float64(0.9918)]
# Data ke-4: [np.float64(0.9638), np.float64(0.011), np.float64(0.0251)]
# Data ke-5: [np.float64(0.9789), np.float64(0.0072), np.float64(0.0139)]
#
# Fungsi Objektif Iterasi 12 (J12): 1.762196
#
# === Iterasi 13 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50720123 7.50720123]
# Cluster 2: [1.25094416 2.25094416]
# Cluster 3: [2.85005571 3.85005571]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.002), np.float64(0.9799), np.float64(0.018)]
# Data ke-2: [np.float64(0.0153), np.float64(0.5543), np.float64(0.4304)]
# Data ke-3: [np.float64(0.0018), np.float64(0.0073), np.float64(0.9909)]
# Data ke-4: [np.float64(0.964), np.float64(0.011), np.float64(0.025)]
# Data ke-5: [np.float64(0.979), np.float64(0.0072), np.float64(0.0138)]
#
# Fungsi Objektif Iterasi 13 (J13): 1.761477
#
# === Iterasi 14 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50713738 7.50713738]
# Cluster 2: [1.24315729 2.24315729]
# Cluster 3: [2.84313904 3.84313904]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0019), np.float64(0.981), np.float64(0.0171)]
# Data ke-2: [np.float64(0.0154), np.float64(0.5453), np.float64(0.4394)]
# Data ke-3: [np.float64(0.002), np.float64(0.0079), np.float64(0.9901)]
# Data ke-4: [np.float64(0.9642), np.float64(0.011), np.float64(0.0249)]
# Data ke-5: [np.float64(0.9791), np.float64(0.0072), np.float64(0.0138)]
#
# Fungsi Objektif Iterasi 14 (J14): 1.760993
#
# === Iterasi 15 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50708567 7.50708567]
# Cluster 2: [1.23679623 2.23679623]
# Cluster 3: [2.83737146 3.83737146]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0018), np.float64(0.9819), np.float64(0.0163)]
# Data ke-2: [np.float64(0.0154), np.float64(0.5378), np.float64(0.4468)]
# Data ke-3: [np.float64(0.0021), np.float64(0.0084), np.float64(0.9895)]
# Data ke-4: [np.float64(0.9643), np.float64(0.0109), np.float64(0.0248)]
# Data ke-5: [np.float64(0.9791), np.float64(0.0072), np.float64(0.0137)]
#
# Fungsi Objektif Iterasi 15 (J15): 1.760664
#
# === Iterasi 16 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.5070435 7.5070435]
# Cluster 2: [1.2315725 2.2315725]
# Cluster 3: [2.8325556 3.8325556]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0017), np.float64(0.9826), np.float64(0.0157)]
# Data ke-2: [np.float64(0.0155), np.float64(0.5316), np.float64(0.4529)]
# Data ke-3: [np.float64(0.0023), np.float64(0.0089), np.float64(0.9889)]
# Data ke-4: [np.float64(0.9644), np.float64(0.0109), np.float64(0.0247)]
# Data ke-5: [np.float64(0.9791), np.float64(0.0072), np.float64(0.0137)]
#
# Fungsi Objektif Iterasi 16 (J16): 1.760439
#
# === Iterasi 17 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50700892 7.50700892]
# Cluster 2: [1.22726581 2.22726581]
# Cluster 3: [2.8285308 3.8285308]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0017), np.float64(0.9831), np.float64(0.0152)]
# Data ke-2: [np.float64(0.0155), np.float64(0.5265), np.float64(0.458)]
# Data ke-3: [np.float64(0.0024), np.float64(0.0092), np.float64(0.9884)]
# Data ke-4: [np.float64(0.9645), np.float64(0.0109), np.float64(0.0246)]
# Data ke-5: [np.float64(0.9792), np.float64(0.0071), np.float64(0.0137)]
#
# Fungsi Objektif Iterasi 17 (J17): 1.760284
#
# === Iterasi 18 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50698045 7.50698045]
# Cluster 2: [1.2237045 2.2237045]
# Cluster 3: [2.82516515 3.82516515]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0016), np.float64(0.9836), np.float64(0.0148)]
# Data ke-2: [np.float64(0.0155), np.float64(0.5223), np.float64(0.4622)]
# Data ke-3: [np.float64(0.0025), np.float64(0.0096), np.float64(0.988)]
# Data ke-4: [np.float64(0.9645), np.float64(0.0109), np.float64(0.0246)]
# Data ke-5: [np.float64(0.9792), np.float64(0.0071), np.float64(0.0137)]
#
# Fungsi Objektif Iterasi 18 (J18): 1.760177
#
# === Iterasi 19 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50695693 7.50695693]
# Cluster 2: [1.22075275 2.22075275]
# Cluster 3: [2.82234968 3.82234968]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0016), np.float64(0.984), np.float64(0.0144)]
# Data ke-2: [np.float64(0.0155), np.float64(0.5187), np.float64(0.4658)]
# Data ke-3: [np.float64(0.0025), np.float64(0.0098), np.float64(0.9876)]
# Data ke-4: [np.float64(0.9646), np.float64(0.0109), np.float64(0.0246)]
# Data ke-5: [np.float64(0.9792), np.float64(0.0071), np.float64(0.0136)]
#
# Fungsi Objektif Iterasi 19 (J19): 1.760103
#
# === Iterasi 20 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50693746 7.50693746]
# Cluster 2: [1.21830184 2.21830184]
# Cluster 3: [2.81999395 3.81999395]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0015), np.float64(0.9843), np.float64(0.0142)]
# Data ke-2: [np.float64(0.0155), np.float64(0.5158), np.float64(0.4687)]
# Data ke-3: [np.float64(0.0026), np.float64(0.0101), np.float64(0.9873)]
# Data ke-4: [np.float64(0.9646), np.float64(0.0108), np.float64(0.0245)]
# Data ke-5: [np.float64(0.9793), np.float64(0.0071), np.float64(0.0136)]
#
# Fungsi Objektif Iterasi 20 (J20): 1.760051
#
# === Iterasi 21 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50692131 7.50692131]
# Cluster 2: [1.2162639 2.2162639]
# Cluster 3: [2.81802266 3.81802266]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0015), np.float64(0.9845), np.float64(0.0139)]
# Data ke-2: [np.float64(0.0155), np.float64(0.5133), np.float64(0.4712)]
# Data ke-3: [np.float64(0.0027), np.float64(0.0103), np.float64(0.9871)]
# Data ke-4: [np.float64(0.9647), np.float64(0.0108), np.float64(0.0245)]
# Data ke-5: [np.float64(0.9793), np.float64(0.0071), np.float64(0.0136)]
#
# Fungsi Objektif Iterasi 21 (J21): 1.760015
#
# === Iterasi 22 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50690789 7.50690789]
# Cluster 2: [1.21456745 2.21456745]
# Cluster 3: [2.81637299 3.81637299]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0015), np.float64(0.9848), np.float64(0.0137)]
# Data ke-2: [np.float64(0.0155), np.float64(0.5112), np.float64(0.4732)]
# Data ke-3: [np.float64(0.0027), np.float64(0.0104), np.float64(0.9869)]
# Data ke-4: [np.float64(0.9647), np.float64(0.0108), np.float64(0.0245)]
# Data ke-5: [np.float64(0.9793), np.float64(0.0071), np.float64(0.0136)]
#
# Fungsi Objektif Iterasi 22 (J22): 1.759990
#
# === Iterasi 23 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50689672 7.50689672]
# Cluster 2: [1.21315401 2.21315401]
# Cluster 3: [2.81499244 3.81499244]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0015), np.float64(0.9849), np.float64(0.0136)]
# Data ke-2: [np.float64(0.0155), np.float64(0.5095), np.float64(0.4749)]
# Data ke-3: [np.float64(0.0027), np.float64(0.0106), np.float64(0.9867)]
# Data ke-4: [np.float64(0.9647), np.float64(0.0108), np.float64(0.0244)]
# Data ke-5: [np.float64(0.9793), np.float64(0.0071), np.float64(0.0136)]
#
# Fungsi Objektif Iterasi 23 (J23): 1.759973
#
# === Iterasi 24 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50688742 7.50688742]
# Cluster 2: [1.21197552 2.21197552]
# Cluster 3: [2.81383714 3.81383714]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0015), np.float64(0.9851), np.float64(0.0135)]
# Data ke-2: [np.float64(0.0155), np.float64(0.5081), np.float64(0.4764)]
# Data ke-3: [np.float64(0.0028), np.float64(0.0107), np.float64(0.9865)]
# Data ke-4: [np.float64(0.9648), np.float64(0.0108), np.float64(0.0244)]
# Data ke-5: [np.float64(0.9793), np.float64(0.0071), np.float64(0.0136)]
#
# Fungsi Objektif Iterasi 24 (J24): 1.759961
#
# === Iterasi 25 ===
#
# Pusat Cluster (Centroids):
# Cluster 1: [6.50687967 7.50687967]
# Cluster 2: [1.21099236 2.21099236]
# Cluster 3: [2.81287036 3.81287036]
#
# Derajat Keanggotaan Baru:
# Data ke-1: [np.float64(0.0014), np.float64(0.9852), np.float64(0.0133)]
# Data ke-2: [np.float64(0.0155), np.float64(0.5069), np.float64(0.4776)]
# Data ke-3: [np.float64(0.0028), np.float64(0.0108), np.float64(0.9864)]
# Data ke-4: [np.float64(0.9648), np.float64(0.0108), np.float64(0.0244)]
# Data ke-5: [np.float64(0.9793), np.float64(0.0071), np.float64(0.0136)]
#
# Fungsi Objektif Iterasi 25 (J25): 1.759952
#
# Konvergen! Iterasi dihentikan.

# %% [markdown]
# implementasi data iris 3 cluster
